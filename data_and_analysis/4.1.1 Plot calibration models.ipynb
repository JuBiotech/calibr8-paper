# %% [markdown]
# # Description
# This notebook makes diagnostic/comparative plots of the calibration models in the manuscript.

# %%
import plotting

# %%
plotting.plot_glucose_cmodels(
    "4.1.1 CM_glucose_linear+logistic", residual_type="relative"
)

# %%
plotting.plot_biomass_cmodel("4.1.1 CM_CDW", residual_type="relative")

# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2021-05-05T18:43:42.613188+02:00
#
# Python implementation: CPython
# Python version       : 3.7.9
# IPython version      : 7.19.0
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# CPU cores   : 6
# Architecture: 64bit
